# %% [markdown]
# # **Fase 02: Entendimeinto de los Datos**
# La fase de Entendimiento de los Datos es la segunda etapa de la metodología CRISP-DM (Cross-Industry Standard Process for Data Mining) y juega un papel fundamental en el éxito de cualquier proyecto de minería de datos.
#
# Esta fase se centra en la recopilación, exploración y comprensión de los datos disponibles para garantizar que sean adecuados para cumplir con los objetivos definidos en la fase anterior (Entendimiento del Negocio).

# %% [markdown]
# ---

# %% [markdown]
# ## **Libreria Pandas (Análisis datos)**
# Pandas es una biblioteca de Python de código abierto que se utiliza principalmente para el análisis de datos y la manipulación de datos estructurados. La biblioteca proporciona estructuras de datos flexibles y de alto rendimiento diseñadas para facilitar la manipulación de datos y el análisis estadístico en Python.
#
# * Las estructuras de datos principales en Pandas son los objetos Series y DataFrame. Un **Series** es un arreglo unidimensional etiquetado de datos, mientras que un **DataFrame** es una estructura de datos bidimensional etiquetada con columnas de tipos potencialmente diferentes. Estos objetos permiten trabajar con datos estructurados y realizar operaciones como selección, filtrado, agrupamiento, fusión y pivote.
#
# * Además, Pandas también proporciona funciones para leer y escribir datos desde y hacia varios formatos, incluyendo archivos CSV, Excel, SQL, JSON, HTML y más.

# %% [markdown]
# # **Sintaxis**

# %%
#Instalación de la libreria pandas en colab
# !pip install pandas

#Instalación de la libreria pandas en VSCode
# pip install pandas

#:::::::::::::::::::::::::::::::::::::::::::::::::

#Importación de la libreria pandas con alias de pd
import pandas as pd

#NOTA: No ejecutar los comandos al tiempo

# %% [markdown]
# # **Atributos**
#
# Pandas tiene varios atributos útiles que proporcionan información sobre las estructuras de datos que estamos trabajando. Algunos de los atributos más comunes de Pandas son:
#
# * **`shape`**: devuelve una tupla que representa la forma (número de filas y columnas) del DataFrame.
# * **` index`**: devuelve la etiqueta de índice de las filas del DataFrame.
# * **`columns`**: devuelve la etiqueta de las columnas del DataFrame.
# * **`dtypes`**: devuelve los tipos de datos de las columnas del DataFrame.
# * **`values`**: devuelve los valores del DataFrame como un ndarray.
# * **`empty`**: devuelve True si el DataFrame está vacío, False en caso contrario.
# * **`size`**: devuelve el número total de elementos en el DataFrame.
# * **`ndim`**: devuelve la cantidad de dimensiones del DataFrame (1 para Series, 2 para DataFrame).

# %%
import pandas as pd

# Crear un DataFrame
datos = pd.DataFrame ({
   'Nombre': ['Juan', 'Ana', 'Pedro', 'Lucia'],
   'Edad': [25, 30, 28, 22],
   'estado': [True, False, True, True]
    })

# Imprimir la forma del DataFrame
# print(datos.shape)

# # Imprimir las etiquetas de índice
# print(datos.index)

# # Imprimir las etiquetas de columnas
# print(datos.columns)

# # Imprimir los tipos de datos de las columnas
# print(datos.dtypes)

# # Imprimir los valores del DataFrame
# print(datos.values)

# # Imprimir si el DataFrame está vacío
# print(datos.empty)

# # Imprimir el número total de elementos en el DataFrame
# print(datos.size)

# # Imprimir la cantidad de dimensiones del DataFrame
# print(datos.ndim)

# %% [markdown]
# # **Métodos**
# Algunos de los métodos más comunes de Pandas son los siguientes:
#
# * **`pd.read_csv()`**: lee un archivo CSV y lo convierte en un DataFrame de Pandas.
# * **`df.head()`**: devuelve las primeras filas de un DataFrame.
# * **`df.tail()`**: devuelve las últimas filas de un DataFrame.
# * **`df.info()`**: muestra información sobre un DataFrame, incluyendo su tamaño y tipo de datos.
# * **`df.describe()`**: proporciona estadísticas descriptivas para un DataFrame, como la media, la desviación estándar, el mínimo y el máximo.
# * **`df.dropna()`**: elimina las filas que contienen valores nulos o faltantes de un DataFrame.
# * **`df.fillna()`**: rellena los valores nulos o faltantes de un DataFrame con un valor especificado.
# * **`df.groupby()`**: agrupa las filas de un DataFrame según los valores de una o más columnas y realiza operaciones agregadas en cada grupo.
# * **`df.merge()`**: combina dos DataFrames en uno solo mediante una columna común.
# * **`df.pivot_table()`**: crea una tabla dinámica a partir de un DataFrame.
# * **`df.plot()`**: crea un gráfico a partir de los datos de un DataFrame.
# * **`df.to_csv()`**: guarda un DataFrame como un archivo CSV.

# %% [markdown]
# # **Gestion de archivos**
#
# # Archivos Planos
#
# `import pandas as pd`
#
# `dataframe = pd.read_csv(filepath_or_buffer, sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, dtype=None)`
#
# **Parametros:**
#
# * **`filepath_or_buffer`**: es la ruta del archivo CSV que se desea leer. Puede ser una ruta absoluta o relativa.
# * **`sep:`** es el delimitador que se utiliza para separar los campos en el archivo CSV. Por defecto es ','.
# * **`delimiter`**: también es un delimitador que se utiliza para separar los campos en el archivo CSV. Si se especifica, anula el valor de sep.
# * **`header`**: indica la fila del archivo CSV que se utilizará como encabezado de la tabla. Por defecto es 'infer', lo que significa que Pandas utiliza la primera fila del archivo CSV como encabezado.
# * **`names`**: es una lista de nombres que se utilizarán como encabezados de la tabla. Si se especifica, anula el valor de header.
# * **`index_col`**: indica la columna que se utilizará como índice de la tabla. Por defecto es None, lo que significa que no se utiliza ninguna columna como índice.
# * **`usecols`**: es una lista de nombres de columnas o índices de columnas que se desean leer del archivo CSV.
# * **`dtype`**: es

# %%
import pandas as pd
datasetPlano = pd.read_csv('CalificacionesTXT.csv', sep=',')

# Uso de los principales metodos
# print(datasetPlano)
datasetPlano
# Out:
#     ITEM   NOMBRES  APELLIDOS        Programa     Genero Matematicas Español  \
# 0      1      Juan     García    Contabilidad  Masculino        1,66    2,19
# 1      2     María      Pérez        Mercadeo   Femenino        3,21    2,54
# 2      3     Pedro  Fernández        Sistemas  Masculino        3,10    3,11
# 3      4       Ana    Sánchez  Administracion   Femenino         NaN    2,50
# 4      5      Luis   González           Salud  Masculino        2,91    2,59
# 5      6     Lucía   Martínez           Salud   Femenino        3,95    1,88
# 6      7     Diego      López  Administracion  Masculino        4,20    1,69
# 7      8  Fernanda     Torres        Sistemas   Femenino        4,08    1,68
# 8      9    Miguel     Flores        Mercadeo  Masculino        4,06    3,64
# 9     10  Carolina  Hernández    Contabilidad   Femenino        2,55    3,75
# 10    11     Sofía       Díaz    Contabilidad   Femenino        1,79    3,94
# 11    12    Javier     Romero        Mercadeo  Masculino         NaN    2,47
# 12    13   Valeria       Ruiz        Sistemas   Femenino        3,27    1,91
# 13    14     Elena    Álvarez  Administracion   Femenino        2,43    3,22
# 14    15    Andrés      Gómez           Salud  Masculino        3,59    3,27
# 15    16     Pedro      López    Contabilidad  Masculino        4,08    1,68
# 16    17       Ana     Torres        Mercadeo   Femenino        4,06    3,64
# 17    18      Luis     Flores        Sistemas  Masculino        2,55    3,75
# 18    19     Lucía      Gómez        Sistemas   Femenino        1,79    3,94
# 19    20    Alvaro      Perez        Sistemas  Masculino        4,05       5
#
#    Ciencias Idiomas
# 0      3,56    2,58
# 1      1,98    3,76
# 2      2,62    2,42
# 3      3,66    1,93
# 4      2,45     NaN
# 5      2,67    1,69
# 6      2,36    3,24
# 7      4,16    2,94
# 8       NaN    3,28
# 9      1,84    3,17
# 10     3,70    2,16
# 11     2,25     NaN
# 12     3,40    2,27
# 13     2,27    2,36
# 14     1,97    2,41
# 15     4,16    2,94
# 16     4,31    3,28
# 17     1,84    3,17
# 18     3,70    2,16
# 19      3,7       4

# %% [markdown]
# # Archivos de Excel
# `import pandas as pd`
# `data = pd.read_excel('ruta/archivo.xlsx', sheet_name='nombre_hoja', header=0, index_col=0)`
#
# Parametros: **texto en negrita**
# * **`'ruta/archivo.xlsx'`**: es la ruta y nombre del archivo Excel que se desea leer.
# * **`'nombre_hoja'`**: es el nombre de la hoja dentro del archivo que se desea leer. Si no se especifica este argumento, se leerá la primera hoja por defecto.
# * **`header=0`**: indica que la primera fila del archivo contiene los nombres de las columnas.
# * **`index_col=0`**: indica que la primera columna del archivo contiene los índices de las filas.

# %%
# Gestion de archivos excel
import pandas as pd
datasetExcel = pd.read_excel('Calificaciones.xlsx')

# Uso de los principales metodos para informacion general del dataset
# print(datasetExcel)
datasetExcel
# Out:
#     ITEM   NOMBRES  APELLIDOS        Programa     Genero  Matematicas  \
# 0      1      Juan     García    Contabilidad          M         1.66
# 1      2     María      Pérez        Mercadeo   Femenino         3.21
# 2      3     Pedro  Fernández        Sistemas  Masculino         3.10
# 3      4       Ana    Sánchez  Administracion          F          NaN
# 4      5      Luis   González           Salud  Masculino         2.91
# 5      6     Lucía   Martínez           Salud        NaN         3.95
# 6      7     Diego      López  Administracion  Masculino         4.20
# 7      8  Fernanda     Torres        Sistemas   Femenino         4.08
# 8      9    Miguel     Flores        Mercadeo  Masculino         4.06
# 9     10  Carolina  Hernández    Contabilidad   Femenino         2.55
# 10    11     Sofía       Díaz    Contabilidad   Femenino         1.79
# 11    12    Javier     Romero        Mercadeo        NaN          NaN
# 12    13   Valeria       Ruiz        Sistemas   Femenino         3.27
# 13    14     Elena    Álvarez  Administracion   Femenino         2.43
# 14    15    Andrés      Gómez           Salud          M         3.59
# 15    16     Pedro      López    Contabilidad  Masculino         4.08
# 16    17       Ana     Torres        Mercadeo   Femenino         4.06
# 17    18      Luis     Flores        Sistemas  Masculino         2.55
# 18    19     Lucía      Gómez        Sistemas      Mujer         1.79
# 19    20    Alvaro      Perez        Sistemas  Masculino         4.05
#
#     Español  Ciencias  Idiomas
# 0      2.19      3.56     2.58
# 1      2.54      1.98     3.76
# 2      3.11      2.62     2.42
# 3      2.50      3.66     1.93
# 4      2.59      2.45      NaN
# 5      1.88      2.67     1.69
# 6      1.69      2.36     3.24
# 7      1.68      4.16     2.94
# 8      3.64       NaN     3.28
# 9      3.75      1.84     3.17
# 10     3.94      3.70     2.16
# 11     2.47      2.25      NaN
# 12     1.91      3.40     2.27
# 13     3.22      2.27     2.36
# 14     3.27      1.97     2.41
# 15     1.68      4.16     2.94
# 16     3.64      4.31     3.28
# 17     3.75      1.84     3.17
# 18     3.94      3.70     2.16
# 19     5.00      3.70     4.00

# %% [markdown]
# # URLs de GitHub

# %%
# URL de archivo plano en cualquier host - Github
import pandas as pd
url = 'https://raw.githubusercontent.com/majash29/CienciaDatosSENAV02/main/02-ExploracionDatos/DocumentosNB02/CalificacionesTXT.csv'
datasetExcelURL = pd.read_csv(url, sep=',')

# Uso de los principales metodos para informacion general del dataset
datasetExcelURL
# Out:
#     ITEM   NOMBRES  APELLIDOS        Programa     Genero Matematicas Español  \
# 0      1      Juan     García    Contabilidad  Masculino        1,66    2,19
# 1      2     María      Pérez        Mercadeo   Femenino        3,21    2,54
# 2      3     Pedro  Fernández        Sistemas  Masculino        3,10    3,11
# 3      4       Ana    Sánchez  Administracion   Femenino         NaN    2,50
# 4      5      Luis   González           Salud  Masculino        2,91    2,59
# 5      6     Lucía   Martínez           Salud   Femenino        3,95    1,88
# 6      7     Diego      López  Administracion  Masculino        4,20    1,69
# 7      8  Fernanda     Torres        Sistemas   Femenino        4,08    1,68
# 8      9    Miguel     Flores        Mercadeo  Masculino        4,06    3,64
# 9     10  Carolina  Hernández    Contabilidad   Femenino        2,55    3,75
# 10    11     Sofía       Díaz    Contabilidad   Femenino        1,79    3,94
# 11    12    Javier     Romero        Mercadeo  Masculino         NaN    2,47
# 12    13   Valeria       Ruiz        Sistemas   Femenino        3,27    1,91
# 13    14     Elena    Álvarez  Administracion   Femenino        2,43    3,22
# 14    15    Andrés      Gómez           Salud  Masculino        3,59    3,27
# 15    16     Pedro      López    Contabilidad  Masculino        4,08    1,68
# 16    17       Ana     Torres        Mercadeo   Femenino        4,06    3,64
# 17    18      Luis     Flores        Sistemas  Masculino        2,55    3,75
# 18    19     Lucía      Gómez        Sistemas   Femenino        1,79    3,94
# 19    20    Alvaro      Perez        Sistemas  Masculino        4,05       5
#
#    Ciencias Idiomas
# 0      3,56    2,58
# 1      1,98    3,76
# 2      2,62    2,42
# 3      3,66    1,93
# 4      2,45     NaN
# 5      2,67    1,69
# 6      2,36    3,24
# 7      4,16    2,94
# 8       NaN    3,28
# 9      1,84    3,17
# 10     3,70    2,16
# 11     2,25     NaN
# 12     3,40    2,27
# 13     2,27    2,36
# 14     1,97    2,41
# 15     4,16    2,94
# 16     4,31    3,28
# 17     1,84    3,17
# 18     3,70    2,16
# 19      3,7       4

# %% [markdown]
# # URLs de Googledrive

# %%
# URL de drive
import pandas as pd
url = 'https://docs.google.com/spreadsheets/d/1N0jiRINu2OeLKApWyY0Jwih2ofcnLlbB/edit?usp=sharing&ouid=112617284460207758071&rtpof=true&sd=true'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
datasetExcelURL = pd.read_excel(path,  index_col=0)


# Uso de los principales metodos para informacion general del dataset
datasetExcelURL
# Out:
#        NOMBRES  APELLIDOS        Programa     Genero  Matematicas  Español  \
# ITEM
# 1         Juan     García    Contabilidad          M         1.66     2.19
# 2        María      Pérez        Mercadeo   Femenino         3.21     2.54
# 3        Pedro  Fernández        Sistemas  Masculino         3.10     3.11
# 4          Ana    Sánchez  Administracion          F          NaN     2.50
# 5         Luis   González           Salud  Masculino         2.91     2.59
# 6        Lucía   Martínez           Salud        NaN         3.95     1.88
# 7        Diego      López  Administracion  Masculino         4.20     1.69
# 8     Fernanda     Torres        Sistemas   Femenino         4.08     1.68
# 9       Miguel     Flores        Mercadeo  Masculino         4.06     3.64
# 10    Carolina  Hernández    Contabilidad   Femenino         2.55     3.75
# 11       Sofía       Díaz    Contabilidad   Femenino         1.79     3.94
# 12      Javier     Romero        Mercadeo        NaN          NaN     2.47
# 13     Valeria       Ruiz        Sistemas   Femenino         3.27     1.91
# 14       Elena    Álvarez  Administracion   Femenino         2.43     3.22
# 15      Andrés      Gómez           Salud          M         3.59     3.27
# 16       Pedro      López    Contabilidad  Masculino         4.08     1.68
# 17         Ana     Torres        Mercadeo   Femenino         4.06     3.64
# 18        Luis     Flores        Sistemas  Masculino         2.55     3.75
# 19       Lucía      Gómez        Sistemas      Mujer         1.79     3.94
# 20      Alvaro      Perez        Sistemas  Masculino         4.05     5.00
#
#       Ciencias  Idiomas
# ITEM
# 1         3.56     2.58
# 2         1.98     3.76
# 3         2.62     2.42
# 4         3.66     1.93
# 5         2.45      NaN
# 6         2.67     1.69
# 7         2.36     3.24
# 8         4.16     2.94
# 9          NaN     3.28
# 10        1.84     3.17
# 11        3.70     2.16
# 12        2.25      NaN
# 13        3.40     2.27
# 14        2.27     2.36
# 15        1.97     2.41
# 16        4.16     2.94
# 17        4.31     3.28
# 18        1.84     3.17
# 19        3.70     2.16
# 20        3.70     4.00

# %% [markdown]
# # Base de Datos - Relacionales

# %%
import mysql.connector
from tabulate import tabulate

conexion = mysql.connector.connect(host='localhost',
                                   database='tienda',
                                   user='root',
                                   password='')
if conexion.is_connected():
    cursor = conexion.cursor()
    cursor.execute ("SELECT * FROM categorias")
    result = cursor.fetchall()
    print(tabulate(result, tablefmt="fancy_grid"))
conexion.close()

# %% [markdown]
# # Base de Datos - No Relacionales

# %%
import pymongo

client = pymongo.MongoClient(
    'mongodb+srv://tienda:JjN3m7raTBF5QI45@clustermsc.kshrc2k.mongodb.net/')

db = client['tienda']
categorias_collection = db['categorias']

data = list(categorias_collection.find())
dataset = pd.json_normalize(data)
dataset

db.close()

# %% [markdown]
# # **Ejemplo Práctico**

# %%
# URL de drive
import pandas as pd
url = 'https://docs.google.com/spreadsheets/d/1N0jiRINu2OeLKApWyY0Jwih2ofcnLlbB/edit?usp=sharing&ouid=112617284460207758071&rtpof=true&sd=true'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
datasetExcelURL = pd.read_excel(path,  index_col=0)
datasetExcelURL
# Out:
#        NOMBRES  APELLIDOS        Programa     Genero  Matematicas  Español  \
# ITEM
# 1         Juan     García    Contabilidad          M         1.66     2.19
# 2        María      Pérez        Mercadeo   Femenino         3.21     2.54
# 3        Pedro  Fernández        Sistemas  Masculino         3.10     3.11
# 4          Ana    Sánchez  Administracion          F          NaN     2.50
# 5         Luis   González           Salud  Masculino         2.91     2.59
# 6        Lucía   Martínez           Salud        NaN         3.95     1.88
# 7        Diego      López  Administracion  Masculino         4.20     1.69
# 8     Fernanda     Torres        Sistemas   Femenino         4.08     1.68
# 9       Miguel     Flores        Mercadeo  Masculino         4.06     3.64
# 10    Carolina  Hernández    Contabilidad   Femenino         2.55     3.75
# 11       Sofía       Díaz    Contabilidad   Femenino         1.79     3.94
# 12      Javier     Romero        Mercadeo        NaN          NaN     2.47
# 13     Valeria       Ruiz        Sistemas   Femenino         3.27     1.91
# 14       Elena    Álvarez  Administracion   Femenino         2.43     3.22
# 15      Andrés      Gómez           Salud          M         3.59     3.27
# 16       Pedro      López    Contabilidad  Masculino         4.08     1.68
# 17         Ana     Torres        Mercadeo   Femenino         4.06     3.64
# 18        Luis     Flores        Sistemas  Masculino         2.55     3.75
# 19       Lucía      Gómez        Sistemas      Mujer         1.79     3.94
# 20      Alvaro      Perez        Sistemas  Masculino         4.05     5.00
#
#       Ciencias  Idiomas
# ITEM
# 1         3.56     2.58
# 2         1.98     3.76
# 3         2.62     2.42
# 4         3.66     1.93
# 5         2.45      NaN
# 6         2.67     1.69
# 7         2.36     3.24
# 8         4.16     2.94
# 9          NaN     3.28
# 10        1.84     3.17
# 11        3.70     2.16
# 12        2.25      NaN
# 13        3.40     2.27
# 14        2.27     2.36
# 15        1.97     2.41
# 16        4.16     2.94
# 17        4.31     3.28
# 18        1.84     3.17
# 19        3.70     2.16
# 20        3.70     4.00

# %%
# Devuelve las primeras filas de un DataFrame.
datasetExcelURL.head()
# Out:
#      NOMBRES  APELLIDOS        Programa     Genero  Matematicas  Español  \
# ITEM
# 1       Juan     García    Contabilidad          M         1.66     2.19
# 2      María      Pérez        Mercadeo   Femenino         3.21     2.54
# 3      Pedro  Fernández        Sistemas  Masculino         3.10     3.11
# 4        Ana    Sánchez  Administracion          F          NaN     2.50
# 5       Luis   González           Salud  Masculino         2.91     2.59
#
#       Ciencias  Idiomas
# ITEM
# 1         3.56     2.58
# 2         1.98     3.76
# 3         2.62     2.42
# 4         3.66     1.93
# 5         2.45      NaN

# %%
# Devuelve las ultimas filas de un DataFrame.
datasetExcelURL.tail()
# Out:
#      NOMBRES APELLIDOS      Programa     Genero  Matematicas  Español  \
# ITEM
# 16     Pedro     López  Contabilidad  Masculino         4.08     1.68
# 17       Ana    Torres      Mercadeo   Femenino         4.06     3.64
# 18      Luis    Flores      Sistemas  Masculino         2.55     3.75
# 19     Lucía     Gómez      Sistemas      Mujer         1.79     3.94
# 20    Alvaro     Perez      Sistemas  Masculino         4.05     5.00
#
#       Ciencias  Idiomas
# ITEM
# 16        4.16     2.94
# 17        4.31     3.28
# 18        1.84     3.17
# 19        3.70     2.16
# 20        3.70     4.00

# %%
# Muestra información sobre un DataFrame, incluyendo su tamaño y tipo de datos.
datasetExcelURL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 1 to 20
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   NOMBRES      20 non-null     object
#  1   APELLIDOS    20 non-null     object
#  2   Programa     20 non-null     object
#  3   Genero       18 non-null     object
#  4   Matematicas  18 non-null     float64
#  5   Español      20 non-null     float64
#  6   Ciencias     19 non-null     float64
#  7   Idiomas      18 non-null     float64
# dtypes: float64(4), object(4)
# memory usage: 1.4+ KB

# %%
# Proporciona estadísticas descriptivas para un DataFrame, como la media,
# la desviación estándar, el mínimo y el máximo.
datasetExcelURL.describe()
# Out:
#        Matematicas    Español   Ciencias    Idiomas
# count     18.00000  20.000000  19.000000  18.000000
# mean       3.18500   2.919500   2.978947   2.764444
# std        0.88603   0.943825   0.870229   0.638650
# min        1.66000   1.680000   1.840000   1.690000
# 25%        2.55000   2.120000   2.260000   2.292500
# 50%        3.24000   2.850000   2.670000   2.760000
# 75%        4.05750   3.667500   3.700000   3.222500
# max        4.20000   5.000000   4.310000   4.000000

# %%
# Elimina las filas que contienen valores nulos o faltantes de un DataFrame.
# datasetExcelURL.dropna()

# datasetExcelURL.info()
# datasetExcelURL.dropna(inplace=True)
datasetExcelURL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, 1 to 20
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   NOMBRES      15 non-null     object
#  1   APELLIDOS    15 non-null     object
#  2   Programa     15 non-null     object
#  3   Genero       15 non-null     object
#  4   Matematicas  15 non-null     float64
#  5   Español      15 non-null     float64
#  6   Ciencias     15 non-null     float64
#  7   Idiomas      15 non-null     float64
# dtypes: float64(4), object(4)
# memory usage: 1.1+ KB

# %%
# Rellena los valores nulos o faltantes de un DataFrame con un valor especificado.
# datasetExcelURL.fillna()

# datasetExcelURL.info()
# datasetExcelURL.fillna(0, inplace=True)
# datasetExcelURL.info()
datasetExcelURL.head()
# Out:
#      NOMBRES  APELLIDOS        Programa     Genero  Matematicas  Español  \
# ITEM
# 1       Juan     García    Contabilidad          M         1.66     2.19
# 2      María      Pérez        Mercadeo   Femenino         3.21     2.54
# 3      Pedro  Fernández        Sistemas  Masculino         3.10     3.11
# 4        Ana    Sánchez  Administracion          F         0.00     2.50
# 5       Luis   González           Salud  Masculino         2.91     2.59
#
#       Ciencias  Idiomas
# ITEM
# 1         3.56     2.58
# 2         1.98     3.76
# 3         2.62     2.42
# 4         3.66     1.93
# 5         2.45     0.00

# %% [markdown]
# # **Métodos de Agrupación**

# %% [markdown]
# **df.groupby()** es un método de pandas que se utiliza para agrupar filas de un DataFrame según los valores de una o varias columnas y realizar operaciones en cada grupo.
#
# La sintaxis básica del método es la siguiente:
# ```
# dataframe.groupby('columna_a_agrupar').metodo_agregado()
# ```
#
# Donde `'columna_a_agrupar'` es el nombre de la columna que se va a utilizar para agrupar las filas del DataFrame y metodo_agregado() es un método de agregación que se va a aplicar sobre los grupos. Algunos de los métodos de agregación más comunes son **`sum()`, `count()`, `mean()`, `min()`, `max()`**.

# %%
# Copiar un dataset Nuevo
datasetNuevo = datasetExcelURL.copy()

# %%
datasetNuevo.head()
# Out:
#      NOMBRES  APELLIDOS        Programa     Genero  Matematicas  Español  \
# ITEM
# 1       Juan     García    Contabilidad          M         1.66     2.19
# 2      María      Pérez        Mercadeo   Femenino         3.21     2.54
# 3      Pedro  Fernández        Sistemas  Masculino         3.10     3.11
# 4        Ana    Sánchez  Administracion          F         0.00     2.50
# 5       Luis   González           Salud  Masculino         2.91     2.59
#
#       Ciencias  Idiomas
# ITEM
# 1         3.56     2.58
# 2         1.98     3.76
# 3         2.62     2.42
# 4         3.66     1.93
# 5         2.45     0.00

# %%
# Cantidad de estudiantes por programa
# est_programa = datasetNuevo.groupby('Programa').count() # Opc01
# est_programa
# print(est_programa,'\n')
# est_programa_uno = datasetNuevo.groupby('Programa').agg({'Programa': 'count'}) # Opc02
# est_programa_uno
# print(est_programa,'\n')
est_programa_dos = datasetNuevo.groupby('Programa') # Opc03
# est_programa_dos
print(est_programa_dos.size())
# Out:
# Programa
# Administracion    3
# Contabilidad      4
# Mercadeo          4
# Salud             3
# Sistemas          6
# dtype: int64

# %%
est_programa_dos.plot(kind='bar')
# Out:
# Programa
# Administracion    Axes(0.125,0.11;0.775x0.77)
# Contabilidad      Axes(0.125,0.11;0.775x0.77)
# Mercadeo          Axes(0.125,0.11;0.775x0.77)
# Salud             Axes(0.125,0.11;0.775x0.77)
# Sistemas          Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
# Cantidad de estudiantes por genero
est_genero = datasetNuevo.groupby('Genero').agg({'Genero': 'count'})
print(est_genero)

# %%
est_genero.plot(kind='bar')
# Out:
# <Axes: xlabel='Genero'>

# %%
# Cantidad de estudiantes por programa y genero
est_programa_genero = datasetNuevo.groupby(['Genero','Programa']).agg({'Programa': 'count'})
print(est_programa_genero)
# Out:
#                           Programa
# Genero    Programa
# 0         Mercadeo               1
#           Salud                  1
# F         Administracion         1
# Femenino  Administracion         1
#           Contabilidad           2
#           Mercadeo               2
#           Sistemas               2
# M         Contabilidad           1
#           Salud                  1
# Masculino Administracion         1
#           Contabilidad           1
#           Mercadeo               1
#           Salud                  1
#           Sistemas               3
# Mujer     Sistemas               1

# %%
est_programa_genero.plot(kind='barh')
# Out:
# <Axes: ylabel='Programa,Genero'>

# %%
# Cantidad de estudiantes por programa que aprueban Matematicas
aprueba_matematicas = datasetNuevo['Matematicas'] >= 4.0
# print(aprueba_matematicas)
aprueba_matematicas = aprueba_matematicas.replace({False: 'No aprobado', True: 'Aprobado'}) #Opcional
estado_aprueba_matematicas = datasetNuevo.groupby(aprueba_matematicas)['Matematicas'].count()
print(estado_aprueba_matematicas)
# Out:
# Matematicas
# Aprobado        6
# No aprobado    14
# Name: Matematicas, dtype: int64

# %%
estado_aprueba_matematicas.plot(kind='pie')
# Out:
# <Axes: ylabel='Matematicas'>

# %%
# Operaciones y generaion de nuevas columnas
datasetNuevo['Promedio'] = (datasetNuevo['Matematicas'] + datasetNuevo['Español'] + datasetNuevo['Ciencias'] + datasetNuevo['Idiomas']) / 4
datasetNuevo['Estado'] = datasetNuevo['Promedio'].apply(lambda x: 'Aprobado' if x >= 4.0 else 'No aprobado')
datasetNuevo
# Out:
#        NOMBRES  APELLIDOS        Programa     Genero  Matematicas  Español  \
# ITEM
# 1         Juan     García    Contabilidad          M         1.66     2.19
# 2        María      Pérez        Mercadeo   Femenino         3.21     2.54
# 3        Pedro  Fernández        Sistemas  Masculino         3.10     3.11
# 4          Ana    Sánchez  Administracion          F         0.00     2.50
# 5         Luis   González           Salud  Masculino         2.91     2.59
# 6        Lucía   Martínez           Salud          0         3.95     1.88
# 7        Diego      López  Administracion  Masculino         4.20     1.69
# 8     Fernanda     Torres        Sistemas   Femenino         4.08     1.68
# 9       Miguel     Flores        Mercadeo  Masculino         4.06     3.64
# 10    Carolina  Hernández    Contabilidad   Femenino         2.55     3.75
# 11       Sofía       Díaz    Contabilidad   Femenino         1.79     3.94
# 12      Javier     Romero        Mercadeo          0         0.00     2.47
# 13     Valeria       Ruiz        Sistemas   Femenino         3.27     1.91
# 14       Elena    Álvarez  Administracion   Femenino         2.43     3.22
# 15      Andrés      Gómez           Salud          M         3.59     3.27
# 16       Pedro      López    Contabilidad  Masculino         4.08     1.68
# 17         Ana     Torres        Mercadeo   Femenino         4.06     3.64
# 18        Luis     Flores        Sistemas  Masculino         2.55     3.75
# 19       Lucía      Gómez        Sistemas      Mujer         1.79     3.94
# 20      Alvaro      Perez        Sistemas  Masculino         4.05     5.00
#
#       Ciencias  Idiomas  Promedio       Estado
# ITEM
# 1         3.56     2.58    2.4975  No aprobado
# 2         1.98     3.76    2.8725  No aprobado
# 3         2.62     2.42    2.8125  No aprobado
# 4         3.66     1.93    2.0225  No aprobado
# 5         2.45     0.00    1.9875  No aprobado
# 6         2.67     1.69    2.5475  No aprobado
# 7         2.36     3.24    2.8725  No aprobado
# 8         4.16     2.94    3.2150  No aprobado
# 9         0.00     3.28    2.7450  No aprobado
# 10        1.84     3.17    2.8275  No aprobado
# 11        3.70     2.16    2.8975  No aprobado
# 12        2.25     0.00    1.1800  No aprobado
# 13        3.40     2.27    2.7125  No aprobado
# 14        2.27     2.36    2.5700  No aprobado
# 15        1.97     2.41    2.8100  No aprobado
# 16        4.16     2.94    3.2150  No aprobado
# 17        4.31     3.28    3.8225  No aprobado
# 18        1.84     3.17    2.8275  No aprobado
# 19        3.70     2.16    2.8975  No aprobado
# 20        3.70     4.00    4.1875     Aprobado

# %% [markdown]
# **pivot_table()** es un método de pandas que permite crear una tabla dinámica a partir de un DataFrame. Permite reorganizar y resumir los datos de un DataFrame de manera más conveniente.
#
# La sintaxis básica es la siguiente:
#
# ```
# df.pivot_table(
#   values=None, # Columna(s) para aplicar la operación
#   index=None, # Columna(s) a utilizar como índice (filas)
#   columns=None, # Columna(s) a utilizar como columnas
#   aggfunc='mean', # Función de agregación a aplicar a los valores
#   fill_value=None, # Valor a reemplazar los valores faltantes
#   margins=False, # Agregar totales en los bordes
#   margins_name='All' # Nombre de los totales del borde
# )
# ```

# %%
# Tablas de resumen o tablas dinamicas
tabla_dinamica = datasetNuevo.pivot_table(
    values=['Matematicas', 'Español', 'Ciencias', 'Idiomas'],
    index=['Programa', 'Genero'],
    aggfunc='mean',
)

print(tabla_dinamica)
# Out:
#                           Ciencias   Español   Idiomas  Matematicas
# Programa       Genero
# Administracion F             3.660  2.500000  1.930000     0.000000
#                Femenino      2.270  3.220000  2.360000     2.430000
#                Masculino     2.360  1.690000  3.240000     4.200000
# Contabilidad   Femenino      2.770  3.845000  2.665000     2.170000
#                M             3.560  2.190000  2.580000     1.660000
#                Masculino     4.160  1.680000  2.940000     4.080000
# Mercadeo       0             2.250  2.470000  0.000000     0.000000
#                Femenino      3.145  3.090000  3.520000     3.635000
#                Masculino     0.000  3.640000  3.280000     4.060000
# Salud          0             2.670  1.880000  1.690000     3.950000
#                M             1.970  3.270000  2.410000     3.590000
#                Masculino     2.450  2.590000  0.000000     2.910000
# Sistemas       Femenino      3.780  1.795000  2.605000     3.675000
#                Masculino     2.720  3.953333  3.196667     3.233333
#                Mujer         3.700  3.940000  2.160000     1.790000

# %%
# Exportar el dataset procesado a un archivo

# Exportar como un archivo de Excel
datasetNuevo.to_excel('AnalisisDatos.xlsx', index=False)

# Exportar como un archivo de CSV
datasetNuevo.to_csv('AnalisisDatos.csv', index=False)
